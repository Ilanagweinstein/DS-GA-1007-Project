# %% [markdown]
# # Web Scraping the Top 250 Movies on IMDB
#
# description of project from proposal.

# %%
from bs4 import BeautifulSoup
import requests
import re
import numpy as np
import pandas as pd
from selenium import webdriver
#pip install selenium

# %% [markdown]
# ### Part I: Web Scraping Tool
# Creating a function that web scrapes from current page (using selenium), parses the HTML, and stores in a pandas DataFrame.

# %%
def web_scrape_page():
    
    url = driver.current_url
    resp = requests.get(url)
    
    #All info from current driver.page_source scraped
    soup = BeautifulSoup(resp.text,'html.parser')
    
    #Scraping header: movie title and year
    scraped_titles = soup.find_all('h3',{"class":"lister-item-header"})
    
    #Scraping for movie title
    movies = []
    for x in scraped_titles:
        for y in x.find_all('a'):
            movies.append(y.text)
    
    #Scraping for movie year
    years = []
    for x in scraped_titles:
        for y in x.find_all('span'):
            years.append(y.text)
    years = years[1::2]
    
    #Scraping from muted text, which is where the movie details are stored: rating, time, genres
    scraped_details = soup.find_all('p',{"class":"text-muted"})
    details = []
    for x in scraped_details:
        for y in x.find_all('span'):
            details.append(y.text)
    
    #Scraping rating, length of film and genres
    rating_types = np.unique(details[0::5])
    correct_rating_types = []

    for i in range(0,len(rating_types)):
        if 'min' not in rating_types[i]:
            correct_rating_types.append(rating_types[i])
    
    ratings = []
    time = []
    genres = []

    for i in range(0,len(details),5):
        if details[i] in correct_rating_types:
            ratings.append(details[i])
            time.append(details[i+2].strip(' min'))
            genres.append(details[i+4].strip())
        else:
            if details[i-2] == '|':
                ratings.append('Not Rated')
            else:
                ratings.append(details[i-2])
            time.append(details[i].strip(' min'))
            genres.append(details[i+2].strip())

    
    #Scraping from ratings bar
    scraped_ratings_bar = soup.find_all('div',{"class":"ratings-bar"})
    s = []
    for x in scraped_ratings_bar:
        for y in x.find_all('div',{"class":"inline-block ratings-imdb-rating"}):
            s.append(y.text)
    stars = []
    for i in s:
        stars.append(i.strip("\n"))
        
    #Scraping directors 
    directors = []
    for element in soup.find_all(text=re.compile("Director")):
        a = element.nextSibling
        directors.append(a.text)
    
    #Scraping actors
    actors = []
    for element in soup.find_all(text=re.compile("Stars")):
        a = element.nextSibling
        if a is None:
            actors.append('None')
        else:
            actors.append(a.string)
        
    #Scraping from num votes, which is where votes and gross $ are stored
    scraped_nums = soup.find_all('p',{"class":"sort-num_votes-visible"})
    nums = []
    for x in scraped_nums:
        for y in x.find_all('span'):
            nums.append(y.text)
    nums = np.array(nums)
    m = []
    for x in scraped_ratings_bar:
        for y in x.find_all('div',{"class":"inline-block ratings-metascore"}):
            m.append(y.text)
    metascore = []

    for i in range(len(m)):
        metascore.append(int(((((((m[i].strip("\n")).strip(" ")).strip("\n")).strip("Metascore")).strip(" ")).strip("\n")).strip(" ")))
    searchval = "Votes:"
    ind = np.where(nums == searchval)[0]+1
    votes = nums[ind]
    searchval = "Gross:"
    ind = np.where(nums == searchval)[0]+1
    gr = nums[ind]
    gross = []

    for i in range(len(gr)):
        a = gr[i].strip("$")
        gross.append(a.strip("M"))
        
    #Creating DataFrame
    df = pd.DataFrame([movies,years,ratings,time,genres,stars,metascore,votes,gross,directors,actors]).transpose()
    df.columns = ['Movie', 'Year', 'Rating', 'Duration (min)', 'Genres','Stars','Metascore','Votes','Gross ($M)', 'Director','Lead']
    
    return df

# %% [markdown]
# The movies are spread across 5 different webpages. We use our function to scrape each page and concatenate the resulting DataFrames, reindexing the final DataFrame so each movie has it's unique identifier.

# %%
pd.set_option('display.max_rows', None)

# %%
from selenium.common.exceptions import NoSuchElementException
import time

# %%
#Initializing pg DataFrame that will eventually contain all scraped information
pg = pd.DataFrame()

#Using selenium's webdriver to create basic Chrome Options when opening browser
options = webdriver.ChromeOptions()
options.add_argument('--ignore-certificate-errors')
options.add_argument("--test-type")

#Using selenium's webdriver to open Google Chrome with stated options 
#Goes directly to url which is the first page of IMDB Top 250 list  
driver = webdriver.Chrome(options=options)
driver.get("https://www.imdb.com/search/title/?groups=top_250&sort=user_rating")

#Scrape page until there isn't a 'Next »' button
#Merge previous pages (pg) to current page (pg_current) until no pages are remaining
pages_remaining = True

while pages_remaining == True:

    pg_current = web_scrape_page()
    pg = pd.concat([pg,pg_current])

    try:
        next_link = driver.find_element_by_xpath('//a[contains(.,"Next »")]')
        next_link.click()
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        time.sleep(30)

    except NoSuchElementException:
        pages_remaining = False

#Close browser
driver.close()

# %%
movies = pg.reset_index(drop=True)
movies.head()
# Out:
#                                            Movie    Year Rating  \
# 0                       The Shawshank Redemption  (1994)      R
# 1                                  The Godfather  (1972)      R
# 2                                The Dark Knight  (2008)  PG-13
# 3                         The Godfather: Part II  (1974)      R
# 4  The Lord of the Rings: The Return of the King  (2003)  PG-13
#
#   Duration (min)                     Genres Stars Metascore      Votes  \
# 0            142                      Drama   9.3        80  2,166,683
# 1            175               Crime, Drama   9.2       100  1,487,716
# 2            152       Action, Crime, Drama   9.0        84  2,141,633
# 3            202               Crime, Drama   9.0        90  1,036,159
# 4            201  Adventure, Drama, Fantasy   8.9        94  1,538,312
#
#   Gross ($M)              Director            Lead
# 0      28.34        Frank Darabont     Tim Robbins
# 1     134.97  Francis Ford Coppola   Marlon Brando
# 2     534.86     Christopher Nolan  Christian Bale
# 3      57.30  Francis Ford Coppola       Al Pacino
# 4     377.85         Peter Jackson     Elijah Wood

# %% [markdown]
# ### Part II: Data Cleaning
#
# We would like Year to be an integer so we could easily bin for different decades in our visualization. We strip away the paranthesis from the Year series and replace it in the movies DataFrame.

# %%
movies['Year'] = movies['Year'].str.replace('(','')
movies['Year'] = movies['Year'].str.replace(')','')

# %%
movies.head()
# Out:
#                                            Movie  Year Rating Duration (min)  \
# 0                       The Shawshank Redemption  1994      R            142
# 1                                  The Godfather  1972      R            175
# 2                                The Dark Knight  2008  PG-13            152
# 3                         The Godfather: Part II  1974      R            202
# 4  The Lord of the Rings: The Return of the King  2003  PG-13            201
#
#                       Genres Stars Metascore      Votes Gross ($M)  \
# 0                      Drama   9.3        80  2,166,683      28.34
# 1               Crime, Drama   9.2       100  1,487,716     134.97
# 2       Action, Crime, Drama   9.0        84  2,141,633     534.86
# 3               Crime, Drama   9.0        90  1,036,159      57.30
# 4  Adventure, Drama, Fantasy   8.9        94  1,538,312     377.85
#
#                Director            Lead
# 0        Frank Darabont     Tim Robbins
# 1  Francis Ford Coppola   Marlon Brando
# 2     Christopher Nolan  Christian Bale
# 3  Francis Ford Coppola       Al Pacino
# 4         Peter Jackson     Elijah Wood

# %% [markdown]
# Some of the data is not clean. There are 5 movies in which the movie name was included in the Year scraping. These 5 instances have to be dealt with individually before we can convert the whole Year column in the movies DataFrame to integers.

# %%
#Example
movies[movies['Movie']== 'Coco']
# Out:
#    Movie    Year Rating Duration (min)                        Genres Stars  \
# 61  Coco  I 2017     PG            105  Animation, Adventure, Family   8.4
#
#    Metascore    Votes Gross ($M)     Director              Lead
# 61        67  309,244     448.14  Lee Unkrich  Anthony Gonzalez

# %%
#All instances of dirty Year Data
movies['Year'][movies['Year'].str.startswith('I')]
# Out:
# 61     I 2017
# 126    I 2015
# 174    I 2015
# 181    I 2013
# 182    I 2015
# Name: Year, dtype: object

# %%
movies['Year'] = movies['Year'].str.replace('I','')

# %%
movies['Year'] = pd.to_numeric(movies['Year'])

# %% [markdown]
# Now, all the Year data is clean and converted to integers. Below is an example.

# %%
movies.loc[124]
# Out:
# Movie                           Green Book
# Year                                  2018
# Rating                               PG-13
# Duration (min)                         130
# Genres            Biography, Comedy, Drama
# Stars                                  8.2
# Metascore                               94
# Votes                              265,884
# Gross ($M)                            6.39
# Director                    Peter Farrelly
# Lead                       Viggo Mortensen
# Name: 124, dtype: object

# %%
movies['Rating'] = movies['Rating'].str.replace('|','Not Rated')

# %%
movies["Duration (min)"] = movies["Duration (min)"].astype(int)
movies["Stars"] = movies["Stars"].astype(float)
movies['Metascore'] = movies['Metascore'].fillna(0)
movies['Votes'] = movies['Votes'].str.replace(',','')
movies["Votes"] = movies["Votes"].astype(int)
movies['Gross ($M)'] = movies['Gross ($M)'].fillna(0)
movies['Gross ($M)'] = movies['Gross ($M)'].astype(float)

# %%
movies
# Out:
#                                                  Movie  Year     Rating  \
# 0                             The Shawshank Redemption  1994          R
# 1                                        The Godfather  1972          R
# 2                                      The Dark Knight  2008      PG-13
# 3                               The Godfather: Part II  1974          R
# 4        The Lord of the Rings: The Return of the King  2003      PG-13
# 5                                         Pulp Fiction  1994          R
# 6                                     Schindler's List  1993          R
# 7                                         12 Angry Men  1957  Not Rated
# 8                                            Inception  2010      PG-13
# 9                                           Fight Club  1999          R
# 10   The Lord of the Rings: The Fellowship of the Ring  2001      PG-13
# 11                                        Forrest Gump  1994      PG-13
# 12                      The Good, the Bad and the Ugly  1966          R
# 13                                               Joker  2019          R
# 14               The Lord of the Rings: The Two Towers  2002      PG-13
# 15                                          The Matrix  1999          R
# 16                                          Goodfellas  1990          R
# 17      Star Wars: Episode V - The Empire Strikes Back  1980         PG
# 18                     One Flew Over the Cuckoo's Nest  1975          R
# 19                                            Harakiri  1962  Not Rated
# 20                                            Parasite  2019          R
# 21                                            Drishyam  2013  Not Rated
# 22                                        Interstellar  2014      PG-13
# 23                                         City of God  2002          R
# 24                                       Spirited Away  2001         PG
# 25                                 Saving Private Ryan  1998          R
# 26                                      The Green Mile  1999          R
# 27                                   Life Is Beautiful  1997      PG-13
# 28                                               Se7en  1995          R
# 29                            The Silence of the Lambs  1991          R
# 30                  Star Wars: Episode IV - A New Hope  1977         PG
# 31                                       Seven Samurai  1954  Not Rated
# 32                               It's a Wonderful Life  1946  Not Rated
# 33                                   Avengers: Endgame  2019      PG-13
# 34                              Avengers: Infinity War  2018      PG-13
# 35                                            Whiplash  2014          R
# 36                                    The Intouchables  2011          R
# 37                                        The Prestige  2006      PG-13
# 38                                        The Departed  2006          R
# 39                                         The Pianist  2002          R
# 40                                           Gladiator  2000          R
# 41                                  American History X  1998          R
# 42                                  The Usual Suspects  1995          R
# 43                              Léon: The Professional  1994          R
# 44                                       The Lion King  1994          G
# 45                          Terminator 2: Judgment Day  1991          R
# 46                                     Cinema Paradiso  1988          R
# 47                              Grave of the Fireflies  1988  Not Rated
# 48                                  Back to the Future  1985         PG
# 49                        Once Upon a Time in the West  1968      PG-13
# 50                                              Psycho  1960          R
# 51                                          Casablanca  1942         PG
# 52                                  The Great Dictator  1940     Passed
# 53                                        Modern Times  1936          G
# 54                                         City Lights  1931          G
# 55                                          Capharnaüm  2018          R
# 56                                           Andhadhun  2018  Not Rated
# 57                                      Marriage Story  2019          R
# 58                                          Your Name.  2016         PG
# 59                                              Dangal  2016  Not Rated
# 60                   Spider-Man: Into the Spider-Verse  2018         PG
# 61                                                Coco  2017         PG
# 62                                    Django Unchained  2012          R
# 63                               The Dark Knight Rises  2012      PG-13
# 64                                            3 Idiots  2009      PG-13
# 65                                    Taare Zameen Par  2007         PG
# 66                                              WALL·E  2008          G
# 67                                 The Lives of Others  2006          R
# 68                                              Oldboy  2003          R
# 69                                             Memento  2000          R
# 70                                   Princess Mononoke  1997      PG-13
# 71                                              Aliens  1986          R
# 72                         Once Upon a Time in America  1984          R
# 73                             Raiders of the Lost Ark  1981         PG
# 74                                         The Shining  1980          R
# 75                                      Apocalypse Now  1979          R
# 76                                               Alien  1979          R
# 77   Dr. Strangelove or: How I Learned to Stop Worr...  1964         PG
# 78                         Witness for the Prosecution  1957  Not Rated
# 79                                      Paths of Glory  1957  Not Rated
# 80                                         Rear Window  1954         PG
# 81                                        Sunset Blvd.  1950  Not Rated
# 82                                            The Hunt  2012          R
# 83                                      Ford v Ferrari  2019      PG-13
# 84                                        A Separation  2011      PG-13
# 85                                           Incendies  2010          R
# 86                                      Babam ve Oglum  2005  Not Rated
# 87                                         Toy Story 3  2010          G
# 88                                Inglourious Basterds  2009          R
# 89               Eternal Sunshine of the Spotless Mind  2004          R
# 90                                              Amélie  2001          R
# 91                                              Snatch  2000          R
# 92                                 Requiem for a Dream  2000          R
# 93                                     American Beauty  1999          R
# 94                                   Good Will Hunting  1997          R
# 95                                  Children of Heaven  1997         PG
# 96                                          The Bandit  1996      TV-MA
# 97                                           Toy Story  1995          G
# 98                                          Braveheart  1995          R
# 99                                      Reservoir Dogs  1992          R
# 100                                  Full Metal Jacket  1987          R
# 101                                       Come and See  1985  Not Rated
# 102                                            Amadeus  1984          R
# 103                                           Scarface  1983          R
# 104         Star Wars: Episode VI - Return of the Jedi  1983         PG
# 105                                           Das Boot  1981          R
# 106                                        Taxi Driver  1976          R
# 107                                          The Sting  1973         PG
# 108                                 A Clockwork Orange  1971          R
# 109                              2001: A Space Odyssey  1968          G
# 110                             For a Few Dollars More  1965          R
# 111                              To Kill a Mockingbird  1962  Not Rated
# 112                                 Lawrence of Arabia  1962   Approved
# 113                                      The Apartment  1960  Not Rated
# 114                                 North by Northwest  1959  Not Rated
# 115                                            Vertigo  1958         PG
# 116                                Singin' in the Rain  1952          G
# 117                                              Ikiru  1952  Not Rated
# 118                                    Bicycle Thieves  1948  Not Rated
# 119                                   Double Indemnity  1944     Passed
# 120                                       Citizen Kane  1941         PG
# 121                                                  M  1931  Not Rated
# 122                                         Metropolis  1927  Not Rated
# 123                                            The Kid  1921  Not Rated
# 124                                         Green Book  2018      PG-13
# 125          Three Billboards Outside Ebbing, Missouri  2017          R
# 126                                         Inside Out  2015         PG
# 127                                 Gangs of Wasseypur  2012  Not Rated
# 128                           The Secret in Their Eyes  2009          R
# 129                                       The Irishman  2019          R
# 130                                            Warrior  2011      PG-13
# 131                                                 Up  2009         PG
# 132                            The Wolf of Wall Street  2013          R
# 133                                There Will Be Blood  2007          R
# 134                                    Pan's Labyrinth  2006          R
# 135                                     V for Vendetta  2005          R
# 136                                    Rang De Basanti  2006  Not Rated
# 137                                      Batman Begins  2005      PG-13
# 138                                           Downfall  2004          R
# 139                               Howl's Moving Castle  2004         PG
# 140                                   A Beautiful Mind  2001      PG-13
# 141                Lock, Stock and Two Smoking Barrels  1998          R
# 142                                  L.A. Confidential  1997          R
# 143                                               Heat  1995          R
# 144                                             Casino  1995          R
# 145                                         Unforgiven  1992          R
# 146                 Indiana Jones and the Last Crusade  1989      PG-13
# 147                                 My Neighbor Totoro  1988          G
# 148                                           Die Hard  1988          R
# 149                                                Ran  1985          R
# 150                                        Raging Bull  1980          R
# 151                                            Stalker  1979  Not Rated
# 152                    Monty Python and the Holy Grail  1975         PG
# 153                                          Chinatown  1974          R
# 154                                      Andrei Rublev  1966          R
# 155                                   The Great Escape  1963  Not Rated
# 156                                            Yojimbo  1961  Not Rated
# 157                              Judgment at Nuremberg  1961  Not Rated
# 158                                   Some Like It Hot  1959  Not Rated
# 159                                  Wild Strawberries  1957  Not Rated
# 160                                   The Seventh Seal  1957  Not Rated
# 161                                  Dial M for Murder  1954         PG
# 162                                        Tokyo Story  1953  Not Rated
# 163                                    Ace in the Hole  1951  Not Rated
# 164                                           Rashômon  1950  Not Rated
# 165                                      All About Eve  1950     Passed
# 166                                         White Heat  1949  Not Rated
# 167                   The Treasure of the Sierra Madre  1948     Passed
# 168                                      The Red Shoes  1948  Not Rated
# 169                         The Passion of Joan of Arc  1928  Not Rated
# 170                                      The Gold Rush  1925  Not Rated
# 171                                       Sherlock Jr.  1924  Not Rated
# 172                                     The Handmaiden  2016  Not Rated
# 173                                              Logan  2017          R
# 174                                               Room  2015          R
# 175                                   Relatos salvajes  2014          R
# 176                                                 PK  2014  Not Rated
# 177                           The Grand Budapest Hotel  2014          R
# 178                                          Gone Girl  2014          R
# 179                                      Hacksaw Ridge  2016          R
# 180                                   12 Years a Slave  2013          R
# 181                                               Rush  2013          R
# 182                                          Spotlight  2015          R
# 183                                           The Help  2011      PG-13
# 184                                          Prisoners  2013          R
# 185                                 Mad Max: Fury Road  2015          R
# 186                                        Gran Torino  2008          R
# 187       Harry Potter and the Deathly Hallows: Part 2  2011      PG-13
# 188                                     Shutter Island  2010          R
# 189                                Hachi: A Dog's Tale  2009          G
# 190                                       Mary and Max  2009  Not Rated
# 191                           How to Train Your Dragon  2010         PG
# 192                                      Into the Wild  2007          R
# 193                             No Country for Old Men  2007          R
# 194                                Million Dollar Baby  2004      PG-13
# 195                                       Hotel Rwanda  2004      PG-13
# 196                                Munna Bhai M.B.B.S.  2003  Not Rated
# 197                                 Memories of Murder  2003  Not Rated
# 198                                   Infernal Affairs  2002          R
# 199                                  Kill Bill: Vol. 1  2003          R
# 200                                       Finding Nemo  2003          G
# 201                                Catch Me If You Can  2002      PG-13
# 202                                      Amores Perros  2000          R
# 203                  Lagaan: Once Upon a Time in India  2001         PG
# 204                                    The Sixth Sense  1999      PG-13
# 205                                    The Truman Show  1998         PG
# 206                                   The Big Lebowski  1998          R
# 207                               In the Mood for Love  2000         PG
# 208                                      Trainspotting  1996          R
# 209                                              Fargo  1996          R
# 210                                           La Haine  1995  Not Rated
# 211                                     Before Sunrise  1995          R
# 212                                      Jurassic Park  1993      PG-13
# 213                          In the Name of the Father  1993          R
# 214                                 Dead Poets Society  1989         PG
# 215                                              Akira  1988          R
# 216                                 The Princess Bride  1987         PG
# 217                                        Stand by Me  1986          R
# 218                                            Platoon  1986          R
# 219                                       Paris, Texas  1984          R
# 220                 Nausicaä of the Valley of the Wind  1984         PG
# 221                                          The Thing  1982          R
# 222                                       Blade Runner  1982          R
# 223                                   The Elephant Man  1980         PG
# 224                       Monty Python's Life of Brian  1979          R
# 225                                    The Deer Hunter  1978          R
# 226                                              Rocky  1976         PG
# 227                                            Network  1976          R
# 228                                       Barry Lyndon  1975         PG
# 229                                     Cool Hand Luke  1967         GP
# 230                                            Persona  1966  Not Rated
# 231                              The Battle of Algiers  1966  Not Rated
# 232                                      The 400 Blows  1959  Not Rated
# 233                                            Ben-Hur  1959          G
# 234                       The Bridge on the River Kwai  1957         PG
# 235                                  On the Waterfront  1954  Not Rated
# 236                                  The Wages of Fear  1953  Not Rated
# 237                                      The Third Man  1949  Not Rated
# 238                                            Rebecca  1940  Not Rated
# 239                       Mr. Smith Goes to Washington  1939  Not Rated
# 240                                 Gone with the Wind  1939     Passed
# 241                              It Happened One Night  1934  Not Rated
# 242                                        The General  1926     Passed
# 243                            Guardians of the Galaxy  2014      PG-13
# 244                                      Before Sunset  2004          R
# 245                                     Monsters, Inc.  2001          G
# 246                                            Aladdin  1992          G
# 247                                  Castle in the Sky  1986         PG
# 248                                     The Terminator  1984          R
# 249                 Butch Cassidy and the Sundance Kid  1969         PG
#
#      Duration (min)                         Genres  Stars  Metascore    Votes  \
# 0               142                          Drama    9.3         80  2166683
# 1               175                   Crime, Drama    9.2        100  1487716
# 2               152           Action, Crime, Drama    9.0         84  2141633
# 3               202                   Crime, Drama    9.0         90  1036159
# 4               201      Adventure, Drama, Fantasy    8.9         94  1538312
# 5               154                   Crime, Drama    8.9         94  1701165
# 6               195      Biography, Drama, History    8.9         94  1124311
# 7                96                          Drama    8.9         96   620375
# 8               148      Action, Adventure, Sci-Fi    8.8         74  1899250
# 9               139                          Drama    8.8         66  1731068
# 10              178      Adventure, Drama, Fantasy    8.8         92  1553493
# 11              142                 Drama, Romance    8.8         82  1668700
# 12              178                        Western    8.8         90   643109
# 13              122         Crime, Drama, Thriller    8.7         59   513096
# 14              179      Adventure, Drama, Fantasy    8.7         87  1391412
# 15              136                 Action, Sci-Fi    8.7         73  1559767
# 16              146        Biography, Crime, Drama    8.7         90   939134
# 17              124     Action, Adventure, Fantasy    8.7         82  1082769
# 18              133                          Drama    8.7         83   855446
# 19              133                 Drama, History    8.7         85    28485
# 20              132        Comedy, Drama, Thriller    8.6         96    94573
# 21              160         Crime, Drama, Thriller    8.6         74    27351
# 22              169       Adventure, Drama, Sci-Fi    8.6         79  1354085
# 23              130                   Crime, Drama    8.6         96   660982
# 24              125   Animation, Adventure, Family    8.6         91   579344
# 25              169                     Drama, War    8.6         61  1147788
# 26              189          Crime, Drama, Fantasy    8.6         59  1054311
# 27              116         Comedy, Drama, Romance    8.6         65   572952
# 28              127          Crime, Drama, Mystery    8.6         85  1332250
# 29              118         Crime, Drama, Thriller    8.6         90  1174063
# 30              121     Action, Adventure, Fantasy    8.6         98  1151459
# 31              207       Action, Adventure, Drama    8.6         89   293243
# 32              130         Drama, Family, Fantasy    8.6         78   368378
# 33              181       Action, Adventure, Drama    8.5         68   616826
# 34              149      Action, Adventure, Sci-Fi    8.5         88   730369
# 35              106                   Drama, Music    8.5         57   645253
# 36              112       Biography, Comedy, Drama    8.5         66   700882
# 37              130         Drama, Mystery, Sci-Fi    8.5         85  1098788
# 38              151         Crime, Drama, Thriller    8.5         85  1107826
# 39              150        Biography, Drama, Music    8.5         67   667967
# 40              155       Action, Adventure, Drama    8.5         62  1250651
# 41              119                          Drama    8.5         77   976771
# 42              106       Crime, Mystery, Thriller    8.5         64   931138
# 43              110           Action, Crime, Drama    8.5         88   958964
# 44               88    Animation, Adventure, Drama    8.5         75   875110
# 45              137                 Action, Sci-Fi    8.5         80   938003
# 46              155                          Drama    8.5         87   209383
# 47               89          Animation, Drama, War    8.5         80   207148
# 48              116      Adventure, Comedy, Sci-Fi    8.5          0   968894
# 49              165                        Western    8.5          0   280406
# 50              109      Horror, Mystery, Thriller    8.5         97   557174
# 51              102            Drama, Romance, War    8.5        100   489115
# 52              125             Comedy, Drama, War    8.5         96   187324
# 53               87          Comedy, Drama, Family    8.5         99   198923
# 54               87         Comedy, Drama, Romance    8.5         75   153311
# 55              126                          Drama    8.4         94    33020
# 56              139                Crime, Thriller    8.4         79    52852
# 57              136         Comedy, Drama, Romance    8.4         87    31083
# 58              106      Animation, Drama, Fantasy    8.4         81   150380
# 59              161       Action, Biography, Drama    8.4         81   132667
# 60              117   Animation, Action, Adventure    8.4         78   280420
# 61              105   Animation, Adventure, Family    8.4         67   309244
# 62              165                 Drama, Western    8.4         95  1253656
# 63              164               Action, Thriller    8.4         89  1425556
# 64              170                  Comedy, Drama    8.4         77   312197
# 65              165                  Drama, Family    8.4         80   149523
# 66               98   Animation, Adventure, Family    8.4         76   934381
# 67              137       Drama, Mystery, Thriller    8.4         84   332996
# 68              120         Action, Drama, Mystery    8.4         85   474287
# 69              113              Mystery, Thriller    8.4         66  1055565
# 70              134  Animation, Adventure, Fantasy    8.4         94   305313
# 71              137      Action, Adventure, Sci-Fi    8.4         89   615965
# 72              229                   Crime, Drama    8.4         97   287096
# 73              115              Action, Adventure    8.4        100   832817
# 74              146                  Drama, Horror    8.4         77   821423
# 75              147            Drama, Mystery, War    8.4         81   565177
# 76              117                 Horror, Sci-Fi    8.4         95   735807
# 77               95                         Comedy    8.4         80   425082
# 78              116        Crime, Drama, Film-Noir    8.4         92    96847
# 79               88                     Drama, War    8.4         69   162464
# 80              112              Mystery, Thriller    8.4         89   411827
# 81              110               Drama, Film-Noir    8.4         69   185446
# 82              115                          Drama    8.3         55   252105
# 83              152       Action, Biography, Drama    8.3         68    55199
# 84              123                          Drama    8.3         84   203828
# 85              131            Drama, Mystery, War    8.3         70   130024
# 86              108                  Drama, Family    8.3         95    71112
# 87              103   Animation, Adventure, Comedy    8.3         68   709678
# 88              153          Adventure, Drama, War    8.3         79  1166424
# 89              108         Drama, Romance, Sci-Fi    8.3          0   846876
# 90              122                Comedy, Romance    8.3          0   667211
# 91              102                  Comedy, Crime    8.3          0   736574
# 92              102                          Drama    8.3          0   718661
# 93              122                          Drama    8.3          0  1011865
# 94              126                 Drama, Romance    8.3          0   793078
# 95               89           Drama, Family, Sport    8.3          0    56856
# 96              128         Crime, Drama, Thriller    8.3          0    57732
# 97               81   Animation, Adventure, Comedy    8.3          0   825950
# 98              178      Biography, Drama, History    8.3          0   911102
# 99               99         Crime, Drama, Thriller    8.3          0   856655
# 100             116                     Drama, War    8.3         76   628892
# 101             142                     Drama, War    8.3         88    46117
# 102             160      Biography, Drama, History    8.3         65   346338
# 103             170                   Crime, Drama    8.3         58   684938
# 104             131     Action, Adventure, Fantasy    8.3         86   886107
# 105             149     Adventure, Drama, Thriller    8.3         94   216641
# 106             114                   Crime, Drama    8.3         83   664800
# 107             129           Comedy, Crime, Drama    8.3         80   226363
# 108             136           Crime, Drama, Sci-Fi    8.3         82   709638
# 109             149              Adventure, Sci-Fi    8.3         74   560149
# 110             132                        Western    8.3         88   214005
# 111             129                   Crime, Drama    8.3        100   278927
# 112             228    Adventure, Biography, Drama    8.3         94   249750
# 113             125         Comedy, Drama, Romance    8.3         98   149560
# 114             136   Adventure, Mystery, Thriller    8.3        100   279532
# 115             128     Mystery, Romance, Thriller    8.3         99   332140
# 116             103       Comedy, Musical, Romance    8.3         95   203315
# 117             143                          Drama    8.3        100    60899
# 118              89                          Drama    8.3         98   132799
# 119             107        Crime, Drama, Film-Noir    8.3         69   132452
# 120             119                 Drama, Mystery    8.3         88   373018
# 121              99       Crime, Mystery, Thriller    8.3         94   132495
# 122             153                  Drama, Sci-Fi    8.3         89   148946
# 123              68          Comedy, Drama, Family    8.3         80   102156
# 124             130       Biography, Comedy, Drama    8.2         94   265884
# 125             115           Comedy, Crime, Drama    8.2         71   370727
# 126              95   Animation, Adventure, Comedy    8.2         88   558629
# 127             321          Action, Comedy, Crime    8.2         75    72080
# 128             129        Drama, Mystery, Romance    8.2         93   178024
# 129             209        Biography, Crime, Drama    8.2         98   117227
# 130             140                   Drama, Sport    8.2         62   412120
# 131              96   Animation, Adventure, Comedy    8.2         70   872442
# 132             180        Biography, Crime, Drama    8.2         82  1074104
# 133             158                          Drama    8.2         80   476972
# 134             118            Drama, Fantasy, War    8.2         72   585293
# 135             132          Action, Drama, Sci-Fi    8.2         66   973399
# 136             167                  Comedy, Drama    8.2         90   103484
# 137             140              Action, Adventure    8.2         76  1228584
# 138             156      Biography, Drama, History    8.2         73   312912
# 139             119   Animation, Adventure, Family    8.2         85   292701
# 140             135               Biography, Drama    8.2         65   792312
# 141             107                  Comedy, Crime    8.2         86   503905
# 142             138          Crime, Drama, Mystery    8.2         72   504137
# 143             170         Crime, Drama, Thriller    8.2         96   537651
# 144             178                   Crime, Drama    8.2          0   428313
# 145             130                 Drama, Western    8.2          0   350570
# 146             127              Action, Adventure    8.2          0   650612
# 147              86     Animation, Family, Fantasy    8.2          0   248171
# 148             132               Action, Thriller    8.2          0   737444
# 149             162                  Action, Drama    8.2          0   102590
# 150             129        Biography, Drama, Sport    8.2         89   298283
# 151             162                  Drama, Sci-Fi    8.2         93   102662
# 152              91     Adventure, Comedy, Fantasy    8.2         92   473428
# 153             130       Drama, Mystery, Thriller    8.2         87   273550
# 154             205      Biography, Drama, History    8.2         60    40983
# 155             172      Adventure, Drama, History    8.2         97   210023
# 156             110        Action, Drama, Thriller    8.2         75   101605
# 157             179                     Drama, War    8.2         72    63781
# 158             121         Comedy, Music, Romance    8.2         98   227303
# 159              91                 Drama, Romance    8.2         98    87025
# 160              96                 Drama, Fantasy    8.2         98   148390
# 161             105                Crime, Thriller    8.2         84   144773
# 162             136                          Drama    8.2         77    45939
# 163             111               Drama, Film-Noir    8.2         86    26357
# 164              88          Crime, Drama, Mystery    8.2         77   140062
# 165             138                          Drama    8.2         88   112523
# 166             114           Action, Crime, Drama    8.2         79    26227
# 167             126      Adventure, Drama, Western    8.2         71   106429
# 168             135          Drama, Music, Romance    8.2         96    26525
# 169             114      Biography, Drama, History    8.2         75    42446
# 170              95       Adventure, Comedy, Drama    8.2         93    92312
# 171              45        Action, Comedy, Romance    8.2         62    35415
# 172             145       Drama, Romance, Thriller    8.1         74    87665
# 173             137          Action, Drama, Sci-Fi    8.1         90   589083
# 174             118                Drama, Thriller    8.1         72   331422
# 175             122        Comedy, Drama, Thriller    8.1         87   157539
# 176             153         Comedy, Drama, Fantasy    8.1         63   144679
# 177              99       Adventure, Comedy, Crime    8.1         74   652830
# 178             149       Drama, Mystery, Thriller    8.1         73   787353
# 179             139      Biography, Drama, History    8.1         91   386367
# 180             134      Biography, Drama, History    8.1         86   593911
# 181             123        Biography, Drama, Sport    8.1         79   403972
# 182             129        Biography, Crime, Drama    8.1         82   380003
# 183             146                          Drama    8.1         75   401568
# 184             153          Crime, Drama, Mystery    8.1         69   545645
# 185             120      Action, Adventure, Sci-Fi    8.1          0   808417
# 186             116                          Drama    8.1          0   684174
# 187             130      Adventure, Drama, Fantasy    8.1          0   710482
# 188             138              Mystery, Thriller    8.1          0  1040085
# 189              93                  Drama, Family    8.1          0   231495
# 190              92       Animation, Comedy, Drama    8.1          0   154703
# 191              98   Animation, Action, Adventure    8.1          0   627213
# 192             148    Adventure, Biography, Drama    8.1          0   536684
# 193             122         Crime, Drama, Thriller    8.1          0   788983
# 194             132                   Drama, Sport    8.1          0   599407
# 195             121      Biography, Drama, History    8.1          0   319304
# 196             156         Comedy, Drama, Musical    8.1          0    67633
# 197             132           Action, Crime, Drama    8.1          0   108886
# 198             101          Crime, Drama, Mystery    8.1          0   113475
# 199             111        Action, Crime, Thriller    8.1          0   935222
# 200             100   Animation, Adventure, Comedy    8.1         90   892484
# 201             141        Biography, Crime, Drama    8.1         75   748437
# 202             154                Drama, Thriller    8.1         83   211144
# 203             224      Adventure, Drama, Musical    8.1         84    96215
# 204             107       Drama, Mystery, Thriller    8.1         64   863741
# 205             103          Comedy, Drama, Sci-Fi    8.1         90   864185
# 206             117           Comedy, Crime, Sport    8.1         71   681347
# 207              98                 Drama, Romance    8.1         85   110332
# 208              93                          Drama    8.1         83   602880
# 209              98         Crime, Drama, Thriller    8.1         85   576084
# 210              98                   Crime, Drama    8.1         77   135755
# 211             101                 Drama, Romance    8.1         68   246252
# 212             127      Action, Adventure, Sci-Fi    8.1         84   805000
# 213             133               Biography, Drama    8.1         79   145387
# 214             128                  Comedy, Drama    8.1         77   384950
# 215             124       Animation, Action, Drama    8.1         75   147512
# 216              98     Adventure, Family, Fantasy    8.1         92   369463
# 217              89               Adventure, Drama    8.1         78   342022
# 218             120                     Drama, War    8.1         86   359756
# 219             145                          Drama    8.1         57    78438
# 220             117  Animation, Adventure, Fantasy    8.1         89   132362
# 221             109        Horror, Mystery, Sci-Fi    8.1         77   343097
# 222             117       Action, Sci-Fi, Thriller    8.1         77   647265
# 223             124               Biography, Drama    8.1         86   205215
# 224              94                         Comedy    8.1         70   343704
# 225             183                     Drama, War    8.1         83   291542
# 226             120                   Drama, Sport    8.1         89   485929
# 227             121                          Drama    8.1         91   135395
# 228             185      Adventure, Drama, History    8.1         86   136960
# 229             127                   Crime, Drama    8.1         95   152317
# 230              83                Drama, Thriller    8.1         90    90860
# 231             121                     Drama, War    8.1         87    48636
# 232              99                   Crime, Drama    8.1         91    95358
# 233             212      Adventure, Drama, History    8.1         97   206182
# 234             161          Adventure, Drama, War    8.1         73   190571
# 235             108         Crime, Drama, Thriller    8.1         97   132148
# 236             131     Adventure, Drama, Thriller    8.1         87    49931
# 237              93   Film-Noir, Mystery, Thriller    8.1         76   149122
# 238             130        Drama, Mystery, Romance    8.1         90   113777
# 239             129                  Comedy, Drama    8.1         78   100477
# 240             238        Drama, History, Romance    8.1         86   270453
# 241             105                Comedy, Romance    8.1         78    87006
# 242              67      Action, Adventure, Comedy    8.1         84    74042
# 243             121      Action, Adventure, Comedy    8.0         66   984501
# 244              80                 Drama, Romance    8.0          0   215303
# 245              92   Animation, Adventure, Comedy    8.0          0   762779
# 246              90   Animation, Adventure, Comedy    8.0          0   339995
# 247             125    Animation, Adventure, Drama    8.0          0   132175
# 248             107                 Action, Sci-Fi    8.0          0   754269
# 249             110        Biography, Crime, Drama    8.0          0   191816
#
#      Gross ($M)                          Director                   Lead
# 0         28.34                    Frank Darabont            Tim Robbins
# 1        134.97              Francis Ford Coppola          Marlon Brando
# 2        534.86                 Christopher Nolan         Christian Bale
# 3         57.30              Francis Ford Coppola              Al Pacino
# 4        377.85                     Peter Jackson            Elijah Wood
# 5        107.93                 Quentin Tarantino          John Travolta
# 6         96.90                  Steven Spielberg            Liam Neeson
# 7          4.36                      Sidney Lumet            Henry Fonda
# 8        292.58                 Christopher Nolan      Leonardo DiCaprio
# 9         37.03                     David Fincher              Brad Pitt
# 10       315.54                     Peter Jackson            Elijah Wood
# 11       330.25                   Robert Zemeckis              Tom Hanks
# 12         6.10                      Sergio Leone         Clint Eastwood
# 13       192.73                     Todd Phillips        Joaquin Phoenix
# 14       342.55                     Peter Jackson            Elijah Wood
# 15       171.48                    Lana Wachowski           Keanu Reeves
# 16        46.84                   Martin Scorsese         Robert De Niro
# 17       290.48                    Irvin Kershner            Mark Hamill
# 18       112.00                      Milos Forman         Jack Nicholson
# 19       188.02                  Masaki Kobayashi        Tatsuya Nakadai
# 20         7.56                      Bong Joon Ho           Kang-ho Song
# 21        10.06                     Jeethu Joseph               Mohanlal
# 22       216.54                 Christopher Nolan    Matthew McConaughey
# 23       136.80                Fernando Meirelles    Alexandre Rodrigues
# 24        57.60                    Hayao Miyazaki          Daveigh Chase
# 25       100.13                  Steven Spielberg              Tom Hanks
# 26       130.74                    Frank Darabont              Tom Hanks
# 27       322.74                   Roberto Benigni        Roberto Benigni
# 28         0.27                     David Fincher         Morgan Freeman
# 29       858.37                    Jonathan Demme           Jodie Foster
# 30       678.82                      George Lucas            Mark Hamill
# 31        13.09                    Akira Kurosawa         Toshirô Mifune
# 32        13.18                       Frank Capra          James Stewart
# 33        53.09                     Anthony Russo      Robert Downey Jr.
# 34       132.38                     Anthony Russo      Robert Downey Jr.
# 35        32.57                   Damien Chazelle           Miles Teller
# 36       187.71                   Olivier Nakache        François Cluzet
# 37         6.72                 Christopher Nolan         Christian Bale
# 38        23.34                   Martin Scorsese      Leonardo DiCaprio
# 39        19.50                    Roman Polanski           Adrien Brody
# 40       422.78                      Ridley Scott          Russell Crowe
# 41       204.84                         Tony Kaye          Edward Norton
# 42        11.99                      Bryan Singer           Kevin Spacey
# 43       210.61                        Luc Besson              Jean Reno
# 44         5.32                      Roger Allers      Matthew Broderick
# 45         0.00                     James Cameron  Arnold Schwarzenegger
# 46         0.00                Giuseppe Tornatore        Philippe Noiret
# 47         0.00                     Isao Takahata        Tsutomu Tatsumi
# 48         0.00                   Robert Zemeckis         Michael J. Fox
# 49         0.00                      Sergio Leone            Henry Fonda
# 50        32.00                  Alfred Hitchcock        Anthony Perkins
# 51         1.02                    Michael Curtiz        Humphrey Bogart
# 52         0.16                   Charles Chaplin        Charles Chaplin
# 53         0.02                   Charles Chaplin        Charles Chaplin
# 54         1.66                   Charles Chaplin        Charles Chaplin
# 55         1.19                     Nadine Labaki         Zain Al Rafeea
# 56         5.02                   Sriram Raghavan     Ayushmann Khurrana
# 57        12.39                     Noah Baumbach            Adam Driver
# 58       190.24                    Makoto Shinkai       Ryûnosuke Kamiki
# 59       209.73                     Nitesh Tiwari             Aamir Khan
# 60       162.81                   Bob Persichetti          Shameik Moore
# 61       448.14                       Lee Unkrich       Anthony Gonzalez
# 62         6.53                 Quentin Tarantino             Jamie Foxx
# 63         1.22                 Christopher Nolan         Christian Bale
# 64       223.81                   Rajkumar Hirani             Aamir Khan
# 65        11.29                        Aamir Khan        Darsheel Safary
# 66         0.71                    Andrew Stanton              Ben Burtt
# 67        25.54  Florian Henckel von Donnersmarck            Ulrich Mühe
# 68         2.38                    Chan-wook Park           Min-sik Choi
# 69        85.16                 Christopher Nolan             Guy Pearce
# 70         5.32                    Hayao Miyazaki           Yôji Matsuda
# 71       248.16                     James Cameron       Sigourney Weaver
# 72        44.02                      Sergio Leone         Robert De Niro
# 73        83.47                  Steven Spielberg          Harrison Ford
# 74        78.90                   Stanley Kubrick         Jack Nicholson
# 75         0.28              Francis Ford Coppola           Martin Sheen
# 76         8.18                      Ridley Scott       Sigourney Weaver
# 77        36.76                   Stanley Kubrick          Peter Sellers
# 78         0.69                      Billy Wilder           Tyrone Power
# 79         7.10                   Stanley Kubrick           Kirk Douglas
# 80         6.86                  Alfred Hitchcock          James Stewart
# 81       415.00                      Billy Wilder         William Holden
# 82       120.54                 Thomas Vinterberg         Mads Mikkelsen
# 83        34.40                     James Mangold             Matt Damon
# 84        33.23                    Asghar Farhadi           Payman Maadi
# 85        30.33                  Denis Villeneuve           Lubna Azabal
# 86         3.64                       Çagan Irmak         Çetin Tekindor
# 87       130.10                       Lee Unkrich              Tom Hanks
# 88       138.43                 Quentin Tarantino              Brad Pitt
# 89         0.93                     Michel Gondry             Jim Carrey
# 90       191.80                Jean-Pierre Jeunet          Audrey Tautou
# 91        75.60                       Guy Ritchie          Jason Statham
# 92         2.83                  Darren Aronofsky          Ellen Burstyn
# 93         0.00                        Sam Mendes           Kevin Spacey
# 94         0.00                      Gus Van Sant         Robin Williams
# 95         0.00                      Majid Majidi     Mohammad Amir Naji
# 96         0.00                      Yavuz Turgul              Sener Sen
# 97         0.00                     John Lasseter              Tom Hanks
# 98         0.00                        Mel Gibson             Mel Gibson
# 99         0.00                 Quentin Tarantino          Harvey Keitel
# 100       46.36                   Stanley Kubrick         Matthew Modine
# 101       51.97                       Elem Klimov     Aleksey Kravchenko
# 102       45.60                      Milos Forman      F. Murray Abraham
# 103      309.13                    Brian De Palma              Al Pacino
# 104       11.49                  Richard Marquand            Mark Hamill
# 105       28.26                 Wolfgang Petersen        Jürgen Prochnow
# 106      159.60                   Martin Scorsese         Robert De Niro
# 107       56.95                   George Roy Hill            Paul Newman
# 108       15.00                   Stanley Kubrick       Malcolm McDowell
# 109       44.82                   Stanley Kubrick            Keir Dullea
# 110       18.60                      Sergio Leone         Clint Eastwood
# 111       13.28                   Robert Mulligan           Gregory Peck
# 112        3.20                        David Lean          Peter O'Toole
# 113        8.82                      Billy Wilder            Jack Lemmon
# 114        0.06                  Alfred Hitchcock             Cary Grant
# 115        0.33                  Alfred Hitchcock          James Stewart
# 116        5.72                     Stanley Donen             Gene Kelly
# 117        1.59                    Akira Kurosawa        Takashi Shimura
# 118        0.03                  Vittorio De Sica    Lamberto Maggiorani
# 119        1.24                      Billy Wilder         Fred MacMurray
# 120        5.45                      Orson Welles           Orson Welles
# 121       85.08                        Fritz Lang            Peter Lorre
# 122       54.51                        Fritz Lang          Brigitte Helm
# 123      356.46                   Charles Chaplin        Charles Chaplin
# 124        6.39                    Peter Farrelly        Viggo Mortensen
# 125       13.66                   Martin McDonagh      Frances McDormand
# 126      293.00                       Pete Docter            Amy Poehler
# 127      116.90                    Anurag Kashyap         Manoj Bajpayee
# 128       40.22              Juan José Campanella          Ricardo Darín
# 129       37.63                   Martin Scorsese         Robert De Niro
# 130       70.51                    Gavin O'Connor              Tom Hardy
# 131        2.20                       Pete Docter           Edward Asner
# 132      206.85                   Martin Scorsese      Leonardo DiCaprio
# 133        5.51              Paul Thomas Anderson       Daniel Day-Lewis
# 134        4.71                Guillermo del Toro          Ivana Baquero
# 135      170.74                    James McTeigue           Hugo Weaving
# 136        3.90           Rakeysh Omprakash Mehra             Aamir Khan
# 137       64.62                 Christopher Nolan         Christian Bale
# 138       67.44               Oliver Hirschbiegel             Bruno Ganz
# 139       42.44                    Hayao Miyazaki          Chieko Baishô
# 140      101.16                        Ron Howard          Russell Crowe
# 141      197.17                       Guy Ritchie          Jason Flemyng
# 142        1.11                     Curtis Hanson           Kevin Spacey
# 143       83.01                      Michael Mann              Al Pacino
# 144        3.52                   Martin Scorsese         Robert De Niro
# 145        0.00                    Clint Eastwood         Clint Eastwood
# 146        0.00                  Steven Spielberg          Harrison Ford
# 147        0.00                    Hayao Miyazaki         Hitoshi Takagi
# 148        0.00                    John McTiernan           Bruce Willis
# 149        0.00                    Akira Kurosawa        Tatsuya Nakadai
# 150       23.38                   Martin Scorsese         Robert De Niro
# 151        0.23                  Andrei Tarkovsky       Alisa Freyndlikh
# 152        1.23                     Terry Gilliam         Graham Chapman
# 153       29.20                    Roman Polanski         Jack Nicholson
# 154        0.10                  Andrei Tarkovsky    Anatoliy Solonitsyn
# 155       12.10                      John Sturges          Steve McQueen
# 156       25.00                    Akira Kurosawa         Toshirô Mifune
# 157        0.01                    Stanley Kramer          Spencer Tracy
# 158        3.97                      Billy Wilder         Marilyn Monroe
# 159        0.10                    Ingmar Bergman        Victor Sjöström
# 160        0.01                    Ingmar Bergman          Max von Sydow
# 161        5.01                  Alfred Hitchcock            Ray Milland
# 162       10.90                      Yasujirô Ozu             Chishû Ryû
# 163        0.02                      Billy Wilder           Kirk Douglas
# 164        5.45                    Akira Kurosawa         Toshirô Mifune
# 165        0.98              Joseph L. Mankiewicz            Bette Davis
# 166        2.01                       Raoul Walsh           James Cagney
# 167      226.28                       John Huston        Humphrey Bogart
# 168       14.68                    Michael Powell         Anton Walbrook
# 169        3.11               Carl Theodor Dreyer       Maria Falconetti
# 170       10.62                   Charles Chaplin        Charles Chaplin
# 171       59.10                     Buster Keaton          Buster Keaton
# 172      167.77                    Chan-wook Park            Min-hee Kim
# 173       67.21                     James Mangold           Hugh Jackman
# 174       56.67                  Lenny Abrahamson            Brie Larson
# 175       26.95                    Damián Szifron      Darío Grandinetti
# 176       45.06                   Rajkumar Hirani             Aamir Khan
# 177      169.71                      Wes Anderson          Ralph Fiennes
# 178       61.00                     David Fincher            Ben Affleck
# 179      154.06                        Mel Gibson        Andrew Garfield
# 180      148.10                     Steve McQueen       Chiwetel Ejiofor
# 181      381.01                        Ron Howard           Daniel Brühl
# 182      128.01                      Tom McCarthy           Mark Ruffalo
# 183      217.58                       Tate Taylor             Emma Stone
# 184       18.35                  Denis Villeneuve           Hugh Jackman
# 185       74.28                     George Miller              Tom Hardy
# 186      100.49                    Clint Eastwood         Clint Eastwood
# 187       23.53                       David Yates       Daniel Radcliffe
# 188        0.01                   Martin Scorsese      Leonardo DiCaprio
# 189        0.17                   Lasse Hallström           Richard Gere
# 190       70.10                       Adam Elliot          Toni Collette
# 191        0.00                      Dean DeBlois           Jay Baruchel
# 192        0.00                         Sean Penn           Emile Hirsch
# 193        0.00                        Ethan Coen        Tommy Lee Jones
# 194        0.00                    Clint Eastwood           Hilary Swank
# 195        0.00                      Terry George            Don Cheadle
# 196        0.00                   Rajkumar Hirani            Sanjay Dutt
# 197        0.00                      Bong Joon Ho           Kang-ho Song
# 198        0.00                        Andrew Lau               Andy Lau
# 199        0.00                 Quentin Tarantino            Uma Thurman
# 200      380.84                    Andrew Stanton          Albert Brooks
# 201      164.62                  Steven Spielberg      Leonardo DiCaprio
# 202        5.38             Alejandro G. Iñárritu      Emilio Echevarría
# 203        0.07                Ashutosh Gowariker             Aamir Khan
# 204      293.51                M. Night Shyamalan           Bruce Willis
# 205      125.62                        Peter Weir             Jim Carrey
# 206       17.50                         Joel Coen           Jeff Bridges
# 207        2.73                      Kar-Wai Wong    Tony Chiu-Wai Leung
# 208       16.50                       Danny Boyle          Ewan McGregor
# 209       24.61                         Joel Coen        William H. Macy
# 210        0.31                 Mathieu Kassovitz         Vincent Cassel
# 211        5.54                 Richard Linklater            Ethan Hawke
# 212      402.45                  Steven Spielberg              Sam Neill
# 213       25.01                      Jim Sheridan       Daniel Day-Lewis
# 214       95.86                        Peter Weir         Robin Williams
# 215        0.55                   Katsuhiro Ôtomo           Mitsuo Iwata
# 216       30.86                        Rob Reiner             Cary Elwes
# 217       52.29                        Rob Reiner            Wil Wheaton
# 218      138.53                      Oliver Stone          Charlie Sheen
# 219        2.18                       Wim Wenders     Harry Dean Stanton
# 220        0.50                    Hayao Miyazaki         Sumi Shimamoto
# 221       13.78                    John Carpenter           Kurt Russell
# 222       32.87                      Ridley Scott          Harrison Ford
# 223       20.05                       David Lynch        Anthony Hopkins
# 224       48.98                       Terry Jones         Graham Chapman
# 225      117.24                    Michael Cimino         Robert De Niro
# 226       16.22                  John G. Avildsen     Sylvester Stallone
# 227        0.06                      Sidney Lumet           Faye Dunaway
# 228       74.70                   Stanley Kubrick            Ryan O'Neal
# 229       44.91                  Stuart Rosenberg            Paul Newman
# 230        9.60                    Ingmar Bergman         Bibi Andersson
# 231        0.45                  Gillo Pontecorvo         Brahim Hadjadj
# 232        4.36                 François Truffaut      Jean-Pierre Léaud
# 233        9.60                     William Wyler        Charlton Heston
# 234      198.68                        David Lean         William Holden
# 235        4.36                        Elia Kazan          Marlon Brando
# 236        0.23             Henri-Georges Clouzot           Yves Montand
# 237      333.18                        Carol Reed           Orson Welles
# 238        5.82                  Alfred Hitchcock       Laurence Olivier
# 239      289.92                       Frank Capra          James Stewart
# 240      217.35                    Victor Fleming            Clark Gable
# 241       38.40                       Frank Capra            Clark Gable
# 242      102.31                    Clyde Bruckman          Buster Keaton
# 243        0.00                        James Gunn            Chris Pratt
# 244        0.00                 Richard Linklater            Ethan Hawke
# 245        0.00                       Pete Docter          Billy Crystal
# 246        0.00                      Ron Clements          Scott Weinger
# 247        0.00                    Hayao Miyazaki            Anna Paquin
# 248        0.00                     James Cameron  Arnold Schwarzenegger
# 249        0.00                   George Roy Hill            Paul Newman

# %% [markdown]
# # Merging WebScraped Data with Actor Information Data #

# %% [markdown]
# Provided by https://github.com/DeathReaper0965/Movie_ratings_prediction.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set(style='white', color_codes=True, font_scale=1.25)

import os
directory = os.getcwd()

# %%
actors = pd.read_csv(directory + '/actors_mod0.csv', sep=',')

# %%
new_actors = actors.drop(['Unnamed: 11',
       'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14'], 1)

new_actors = new_actors.drop(['dow', 'bname', 'gname','dod','picture pointer', 'notes', 'award'],1)

# %%
new_actors.columns
new_actors = new_actors.rename(columns={'stage-name': "Lead", 'gender': 'Gender', 'dob':"DOB", 'role type':'Role Type'})
new_actors.head()
# Out:
#              Lead Gender      DOB       Role Type
# 0    Willie Aames      M     1960             RU:
# 1      Bud Abbott      M     1895      R:straight
# 2  Diahnne Abbott      F  [1][23]          R:sexy
# 3   George Abbott      M     1887    R:playwright
# 4     John Abbott      M     1905  R:staring eyes

# %%
df_merged = pd.merge(movies, new_actors, how='inner', on= 'Lead')

# %%
df_merged.head()
# Out:
#                     Movie  Year     Rating  Duration (min)  \
# 0           The Godfather  1972          R             175
# 1       On the Waterfront  1954  Not Rated             108
# 2  The Godfather: Part II  1974          R             202
# 3                Scarface  1983          R             170
# 4                    Heat  1995          R             170
#
#                    Genres  Stars  Metascore    Votes  Gross ($M)  \
# 0            Crime, Drama    9.2        100  1487716      134.97
# 1  Crime, Drama, Thriller    8.1         97   132148        4.36
# 2            Crime, Drama    9.0         90  1036159       57.30
# 3            Crime, Drama    8.3         58   684938      309.13
# 4  Crime, Drama, Thriller    8.2         96   537651       83.01
#
#                Director           Lead Gender   DOB          Role Type
# 0  Francis Ford Coppola  Marlon Brando      M  1924      R:modern male
# 1            Elia Kazan  Marlon Brando      M  1924      R:modern male
# 2  Francis Ford Coppola      Al Pacino      M  1939  R:malevolent lead
# 3        Brian De Palma      Al Pacino      M  1939  R:malevolent lead
# 4          Michael Mann      Al Pacino      M  1939  R:malevolent lead

# %% [markdown]
# Transforming DOB column to contain all valid years, and creating a column to represent actors age at the time the movie was released.

# %%
#possible to make this process automated?
a = df_merged['DOB'].str.startswith('1')
b = pd.DataFrame(a)

# %%
df_merged['Lead'][b['DOB']== False]
# Out:
# 9        Liam Neeson
# 27    Morgan Freeman
# 54        Jim Carrey
# 55        Jim Carrey
# 61    Matthew Modine
# 76        Bruno Ganz
# 96     Charlie Sheen
# Name: Lead, dtype: object

# %%
df_merged.loc[9,'DOB'] = '1952'
df_merged.loc[27,'DOB'] = '1937'
df_merged.loc[54,'DOB'] = '1962'
df_merged.loc[55,'DOB'] = '1962'
df_merged.loc[61,'DOB'] = '1959'
df_merged.loc[76,'DOB'] = '1941'
df_merged.loc[96,'DOB'] = '1965'

# %%
df_merged['DOB'] = df_merged['DOB'].astype(float)
df_merged['Age'] = df_merged['Year'] - df_merged['DOB']
df_merged.head()
# Out:
#                     Movie  Year     Rating  Duration (min)  \
# 0           The Godfather  1972          R             175
# 1       On the Waterfront  1954  Not Rated             108
# 2  The Godfather: Part II  1974          R             202
# 3                Scarface  1983          R             170
# 4                    Heat  1995          R             170
#
#                    Genres  Stars  Metascore    Votes  Gross ($M)  \
# 0            Crime, Drama    9.2        100  1487716      134.97
# 1  Crime, Drama, Thriller    8.1         97   132148        4.36
# 2            Crime, Drama    9.0         90  1036159       57.30
# 3            Crime, Drama    8.3         58   684938      309.13
# 4  Crime, Drama, Thriller    8.2         96   537651       83.01
#
#                Director           Lead Gender     DOB          Role Type   Age
# 0  Francis Ford Coppola  Marlon Brando      M  1924.0      R:modern male  48.0
# 1            Elia Kazan  Marlon Brando      M  1924.0      R:modern male  30.0
# 2  Francis Ford Coppola      Al Pacino      M  1939.0  R:malevolent lead  35.0
# 3        Brian De Palma      Al Pacino      M  1939.0  R:malevolent lead  44.0
# 4          Michael Mann      Al Pacino      M  1939.0  R:malevolent lead  56.0

# %%
#NEED TO REDO MERGE
#show work for merging? 
actors = pd.read_excel(directory + '/final_movies.xlsx')

# %%
movies = actors.copy()

# %%
movies.iloc[60]
# Out:
# Unnamed: 0                              60
# Movie                       Reservoir Dogs
# Year                                  1992
# Rating                              99 min
# Duration (min)    \nCrime, Drama, Thriller
# Genres                                 NaN
# Stars                                  8.3
# Metascore                              NaN
# Votes                              856,127
# Gross ($M)                             NaN
# Director                 Quentin Tarantino
# Lead                         Harvey Keitel
# Gender                                   M
# DOB                                   1947
# Role Type                              RU:
# Age                                     45
# Genre 1                                NaN
# Genre 2                                NaN
# Genre 3                                NaN
# Name: 60, dtype: object

# %%
movies.columns
# Out:
# Index(['Unnamed: 0', 'Movie', 'Year', 'Rating', 'Duration (min)', 'Genres',
#        'Stars', 'Metascore', 'Votes', 'Gross ($M)', 'Director', 'Lead',
#        'Gender', 'DOB', 'Role Type', 'Age', 'Genre 1', 'Genre 2', 'Genre 3'],
#       dtype='object')
